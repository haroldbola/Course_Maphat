# %% [markdown]
# # Exercise 1
# ```In this exercise you will experience with pandas, matplotlib and numpy. This are main tools we are going to use later in course, and which are extremly useful in a variety of tasks. For each question, answer it in cells directly beneath it.```
#
# ```You are more than encourged to read relevant parts, mainly from ``` [pandas' API](https://pandas.pydata.org/pandas-docs/stable/reference/index.html)
#
# ```~ Ittai Haran```

# %% [markdown]
# ## DataFrame basics
#
# ```A few of the fundamental routines for selecting, sorting, adding and aggregating data in DataFrames```

# %% [markdown]
# ```import numpy and pandas```

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ```Consider the following Python dictionary `data` and Python list `labels`:```
#
# ``` python
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
#
# ```Create a DataFrame `df` from this dictionary `data` which has the index `labels`.```

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df = pd.DataFrame(data,index=labels)
df
# Out:
#    age animal priority  visits
# a  2.5    cat      yes       1
# b  3.0    cat      yes       3
# c  0.5  snake       no       2
# d  NaN    dog      yes       3
# e  5.0    dog       no       2
# f  2.0    cat       no       3
# g  4.5  snake       no       1
# h  NaN    cat      yes       1
# i  7.0    dog       no       2
# j  3.0    dog       no       1

# %% [markdown]
# ```Display a summary of the basic information about this DataFrame and its data using the decribe and the info functions```

# %%
print(pd.DataFrame.describe(df))
print(pd.DataFrame.info(df))
# Out:
#             age     visits
# count  8.000000  10.000000
# mean   3.437500   1.900000
# std    2.007797   0.875595
# min    0.500000   1.000000
# 25%    2.375000   1.000000
# 50%    3.000000   2.000000
# 75%    4.625000   2.750000
# max    7.000000   3.000000
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
# age         8 non-null float64
# animal      10 non-null object
# priority    10 non-null object
# visits      10 non-null int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes
# None

# %% [markdown]
# ```Return the first 3 rows of the DataFrame `df`. Do it two times: use head and iloc```

# %%
print(df.head(3))
df.iloc[:,1]
# Out:
#    age animal priority  visits
# a  2.5    cat      yes       1
# b  3.0    cat      yes       3
# c  0.5  snake       no       2
# a      cat
# b      cat
# c    snake
# d      dog
# e      dog
# f      cat
# g    snake
# h      cat
# i      dog
# j      dog
# Name: animal, dtype: object

# %% [markdown]
# ```Select just the 'animal' and 'age' columns from the DataFrame `df`.```

# %%
df[['animal','age']]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %% [markdown]
# ```Select the data in rows `[3, 4, 8]` *and* in columns `['animal', 'age']`.```

# %%
df.loc[['c','d','h'],['animal','age']]
# Out:
#   animal  age
# c  snake  0.5
# d    dog  NaN
# h    cat  NaN

# %% [markdown]
# ```Select only the rows where the number of visits is greater than 3. Pandas supports two useful APIs:
# (df[boolean list/series]) returns the rows for which the value is True
# (df[column] > num) returns a boolean series```

# %%
df[df['visits']>3]
# Out:
# Empty DataFrame
# Columns: [age, animal, priority, visits]
# Index: []

# %% [markdown]
# ```Select the rows where the age is missing, i.e. is `NaN`.```

# %%
df.loc[pd.isnull(df['age'])]
# Out:
#    age animal priority  visits
# d  NaN    dog      yes       3
# h  NaN    cat      yes       1

# %% [markdown]
# ```Select the rows where the animal is a cat *and* the age is less than 3. You can use logical operands: &, |, ~```

# %%
df.loc[(df['animal']=="cat") & (df['age']<3)]
# Out:
#    age animal priority  visits
# a  2.5    cat      yes       1
# f  2.0    cat       no       3

# %% [markdown]
# ```Select the rows the age is between 2 and 4 (inclusive).```

# %%
df.loc[(df['age']<4)&(df['age']>2)]
# Out:
#    age animal priority  visits
# a  2.5    cat      yes       1
# b  3.0    cat      yes       3
# j  3.0    dog       no       1

# %% [markdown]
# ```Change the age in row 'f' to 1.5.```

# %%
df.at['f','age'] =1.5
df
# Out:
#    age animal priority  visits
# a  2.5    cat      yes       1
# b  3.0    cat      yes       3
# c  0.5  snake       no       2
# d  NaN    dog      yes       3
# e  5.0    dog       no       2
# f  1.5    cat       no       3
# g  4.5  snake       no       1
# h  NaN    cat      yes       1
# i  7.0    dog       no       2
# j  3.0    dog       no       1

# %% [markdown]
# ```Calculate the sum of all visits (the total number of visits). Do it twice: using built in pandas functions and using numpy```

# %%
df['visits'].sum()
np.sum(df['visits'])
# Out:
# 19

# %% [markdown]
# ```Calculate the mean age for each different animal in `df`.```

# %%
df.groupby("animal").mean()
# Out:
#              age  visits
# animal
# cat     2.333333     2.0
# dog     5.000000     2.0
# snake   2.500000     1.5

# %% [markdown]
# ```Append a new row 'k' to `df` with your choice of values for each column. Then delete that row to return the original DataFrame.```

# %%
k = pd.DataFrame([(45,'lion','high',4)], columns = ['age' , 'animal', 'priority' , 'visits'], index=['k']) 
df = df.append(k)
df = df.drop("k")

# %% [markdown]
# ```Count the number of each type of animal in `df`.```

# %%
df.groupby("animal").size()
# Out:
# animal
# cat      4
# dog      4
# snake    2
# dtype: int64

# %% [markdown]
# ```Sort `df` first by the values in the 'age' in *decending* order, then by the value in the 'visit' column in *ascending* order. You can use the sort_values function```

# %%
df.sort_values(by=['age'])
df.sort_values(by=['visits'], ascending = True)
# Out:
#    age animal priority  visits
# a  2.5    cat      yes       1
# g  4.5  snake       no       1
# h  NaN    cat      yes       1
# j  3.0    dog       no       1
# c  0.5  snake       no       2
# e  5.0    dog       no       2
# i  7.0    dog       no       2
# b  3.0    cat      yes       3
# d  NaN    dog      yes       3
# f  1.5    cat       no       3

# %% [markdown]
# ```The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be `True` and 'no' should be `False`.```

# %%
df = df.replace("yes",True)
df = df.replace("no",False)
df
# Out:
#    age animal  priority  visits
# a  2.5    cat      True       1
# b  3.0    cat      True       3
# c  0.5  snake     False       2
# d  NaN    dog      True       3
# e  5.0    dog     False       2
# f  1.5    cat     False       3
# g  4.5  snake     False       1
# h  NaN    cat      True       1
# i  7.0    dog     False       2
# j  3.0    dog     False       1

# %% [markdown]
# ```In the 'animal' column, change the 'snake' entries to 'python'.```

# %%
df = df.replace('snake','python')
df
# Out:
#    age  animal  priority  visits
# a  2.5     cat      True       1
# b  3.0     cat      True       3
# c  0.5  python     False       2
# d  NaN     dog      True       3
# e  5.0     dog     False       2
# f  1.5     cat     False       3
# g  4.5  python     False       1
# h  NaN     cat      True       1
# i  7.0     dog     False       2
# j  3.0     dog     False       1

# %% [markdown]
# ```For each animal type and each number of visits, find the mean age. In other words, each row is an animal, each column is a number of visits and the values are the mean ages (hint: use a pivot table).```

# %%
pd.pivot_table(df,index=['animal'])
# Out:
#              age  priority  visits
# animal
# cat     2.333333      0.75     2.0
# dog     5.000000      0.25     2.0
# python  2.500000      0.00     1.5

# %% [markdown]
# ```Now you will be asked to generate your own test data and manipulate it using functions you will have to create.```

# %% [markdown]
# ```Create a dataframe with 1000 rows and 3 columns. The columns are to be the following:```
# ```
#         - age: an integer, uniformly distributed between 20 to 65
#         - skill: a float, normally distributed between 0 and 1, with expected value = 0.5 and standard deviation = 0.3
#         - height: a float with 2 digits after the decimal point, between 1.5 to 2.0
# ```
# ```you might want to use numpy.random```

# %%
data = {'age':np.random.randint(low=20, high=65, size=1000),'skill':np.random.normal(loc=0.5,scale=0.3,size=1000),'height':np.around(np.random.uniform(low=1.5,high=2.0,size=1000),decimals=2)}
df = pd.DataFrame(data)

# %% [markdown]
# ```Add the dataframe a new columns, called salary, when:```
#         <center>$salary = 1000\cdot((age^2)/1000 + 1.7\cdot skill + 0.4\cdot exp(-(height-1.7)^2)$<center>

# %%
df["salary"]=1000*((df["age"]**2))/1000 + 1.7*df["skill"]+0.4*np.exp(-(df["height"]-1.7)**2)
df
# Out:
#      age  height     skill       salary
# 0     45    1.61  0.608185  2026.430687
# 1     38    1.74  0.578404  1445.382647
# 2     55    1.85  0.740362  3026.649716
# 3     54    1.53  0.422284  2917.106488
# 4     41    1.82  0.696433  1682.578217
# 5     50    1.85  0.183577  2500.703181
# 6     31    1.95  0.147161   961.625938
# 7     42    1.82  0.540173  1765.312576
# 8     24    1.99  0.146553   576.616876
# 9     57    1.59  0.552711  3250.334798
# 10    38    1.96  0.937745  1445.968020
# 11    58    1.90  0.929997  3365.965311
# 12    32    1.85 -0.109768  1024.204495
# 13    35    1.99  0.401116  1226.049633
# 14    36    1.96  0.953216  1297.994320
# 15    62    1.75  0.190665  3844.723132
# 16    55    1.78  0.241818  3025.808538
# 17    60    1.85  0.340849  3600.970544
# 18    20    1.62  1.019483   402.130568
# 19    30    1.74  0.803386   901.765118
# 20    39    1.56  0.521069  1522.278054
# 21    55    1.97  0.455731  3026.146620
# 22    64    1.70  0.406489  4097.091031
# 23    49    1.72 -0.009122  2401.384332
# 24    63    1.98  0.204378  3969.717280
# 25    31    1.70  0.341779   961.981024
# 26    61    1.76  0.758386  3722.687818
# 27    30    1.80  0.458259   901.175060
# 28    48    1.90  0.997781  2306.080543
# 29    58    1.64  0.199547  3364.737792
# ..   ...     ...       ...          ...
# 970   37    1.72  0.894113  1370.919832
# 971   37    1.69  0.442250  1370.151785
# 972   58    1.61 -0.033371  3364.340043
# 973   47    1.56  0.616278  2210.439908
# 974   36    1.82  0.461991  1297.179666
# 975   40    1.54  0.578183  1601.372801
# 976   21    1.71  0.264320   441.849304
# 977   54    1.95  0.361075  2916.989593
# 978   26    1.66  0.540656   677.318475
# 979   47    1.87  1.051668  2211.176441
# 980   58    1.64  0.641735  3365.489512
# 981   61    1.72  0.309527  3721.926036
# 982   63    1.61  0.644336  3970.492144
# 983   53    1.88  0.998630  2811.084919
# 984   40    1.94  0.874217  1601.863780
# 985   58    1.76  0.359097  3365.009028
# 986   28    1.99  0.037434   784.431374
# 987   20    1.67  0.522719   401.288262
# 988   57    1.66  0.161600  3249.674080
# 989   41    1.57  0.240224  1681.801678
# 990   48    1.80  0.453994  2305.167809
# 991   55    1.84 -0.190034  3025.069179
# 992   43    1.59  0.324387  1849.946648
# 993   60    1.59  0.698085  3601.581934
# 994   63    1.77  0.327994  3969.955634
# 995   20    1.54  1.219265   402.462640
# 996   51    1.59  0.124041  2601.606059
# 997   53    1.94  0.631244  2810.450726
# 998   28    1.83  0.804966   785.761739
# 999   49    2.00  0.354516  2401.968249
#
# [1000 rows x 4 columns]

# %% [markdown]
# ```Split the dataframe to groups by the age left digit and by the age. for each group compute:```
# ```
#         - the number of rows
#         - the mean salary
#         - the maximum height
# ```
#
# ```To do so, read about the groupby and agg functions is the ``` [pandas API](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html)

# %%
g = df.groupby(by = df["age"]//10%10)
f = df.groupby(by = df["age"])
n_rows_g = g.agg("count").shape[0]
mean_g = g["salary"].mean()
max_height_g = g["height"].agg("max")
print(n_rows_g)
print(mean_g)
print(max_height_g)
# Out:
# 5
# age
# 2     609.000703
# 3    1208.792865
# 4    2015.186729
# 5    2970.085058
# 6    3837.186019
# Name: salary, dtype: float64
# age
# 2    2.00
# 3    1.99
# 4    2.00
# 5    2.00
# 6    1.99
# Name: height, dtype: float64

# %% [markdown]
# ```Now split the dataframe to groups by age. For each group compute the mean salary, divided by the sum of heights.```

# %%
f = df.groupby(by = df["age"])
print(f["salary"].mean()/f["height"].sum())
# Out:
# age
# 20      9.716987
# 21     14.332750
# 22     13.847595
# 23     11.053624
# 24     14.028324
# 25     27.087998
# 26     15.654991
# 27     18.563385
# 28     28.431954
# 29     26.439406
# 30     20.665036
# 31     21.542378
# 32     31.608434
# 33     27.076689
# 34     29.057365
# 35     37.806895
# 36     29.311362
# 37     31.518353
# 38     46.364812
# 39     23.981251
# 40     35.587476
# 41     45.267136
# 42     48.583542
# 43     45.125284
# 44     38.667718
# 45     48.841248
# 46     40.503815
# 47     56.575079
# 48     46.361499
# 49     71.949077
# 50     72.585778
# 51     45.169387
# 52     73.491510
# 53     69.440779
# 54     86.027285
# 55     70.278854
# 56    145.784249
# 57     93.665857
# 58    150.435137
# 59    101.022233
# 60     82.444221
# 61    121.995601
# 62     87.751220
# 63    118.587098
# 64    115.546109
# dtype: float64

# %% [markdown]
# ```Add these lines to your code:```
# ```python
#         import matplotlib.pyplot as plt
#         %matplotlib inline
# ```
#
# ```Now try using the pd.DataFrame.plot function to show your data. Try also using pd.DataFrame.boxplot.```

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
a=pd.Series(f["salary"].mean()/f["height"].sum(),name='value')
a.reset_index().boxplot('value')
plt.show()
a.plot()
plt.show()

# %% [markdown]
# ```Save the result as a csv```

# %%
(f["salary"].mean()/f["height"].sum()).to_csv(r"C:\Users\T8698819\Desktop\limonana\ex.csv")

# %% [markdown]
# ## Working with real-life data

# %% [markdown]
# ```read the csv file entitled house_prices_numeric.csv consider writing the following line of code:```
# ```python
# pd.options.display.max_columns=50
# ```

# %%
from IPython.display import display, HTML
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/roee97/ds_course_ex1/master/house_prices_numeric.csv')

# %% [markdown]
# ```In the following questions, print your answer if possible, draw a graph or visualize it in any other means. When drawing a graph, add a title to it. Answer the following questions (try using a single line of code for each):```
# ```
# - What is oldest house in the dataset (YearBuilt)?
# - What is the highest price (SalePrice) of houses built in that year?
# - What is the mean area (LotArea) of houses?
# - What is the 50-percentile of the area (LotArea) of houses?
# - What is more common: having a fireplace (Fireplaces) in the house, or not having one?
# - What is the mean price (SalePrice) of houses that have swimming pools (PoolArea)?
# - How many houses were sold every year (YrSold)? Draw a graph using plt.plot or pandas.plot
# - What is the distribution of the overall condition of the houses (OverallCond)? Use plt.hist or pandas.hist
# - For every number of fireplaces in a house (Fireplaces), compute the mean price of a house, the mean age of the house (we are in 2019) and the count of distinct FullBath values
# - Take only houses with MSSubClass > 60. Split into groups according to whether or not the MSSubClass is a multiple of 20. For each group compute the mean, max, min and standard deviation of OverallQual
# ```

# %%
df[df["YearBuilt"]== df["YearBuilt"].min()]
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 1349  1350          70         50.0     5250            8            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# 1349       1872          1987         0.0         259  ...           0
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# 1349           54             20          0            0         0        0
#
#       MoSold  YrSold  SalePrice
# 1349      12    2008     122000
#
# [1 rows x 38 columns]

# %%
df[df["YearBuilt"]== df["YearBuilt"].min()]["SalePrice"].max()
# Out:
# 122000

# %%
df["LotArea"].mean()
# Out:
# 10516.828082191782

# %%
df["LotArea"].quantile(0.5)
# Out:
# 9478.5

# %%
df.groupby("Fireplaces").size()[0]>df.groupby("Fireplaces").size()[1:].sum()
# Out:
# False

# %%
df[df["PoolArea"]>0]["SalePrice"].mean()
# Out:
# 288138.5714285714

# %%
plt.plot(df.groupby("YrSold").size())
plt.show()
plt.hist(df["OverallCond"])
# Out:
# (array([  1.,   5.,  25.,  57.,   0., 821., 252., 205.,  72.,  22.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <a list of 10 Patch objects>)

# %%
g = df.groupby("Fireplaces")
print(g["SalePrice"].mean())
print(2019 - g["YearBuilt"].mean())
g["FullBath"].nunique()
# Out:
# Fireplaces
# 0    141331.482609
# 1    211843.909231
# 2    240588.539130
# 3    252000.000000
# Name: SalePrice, dtype: float64
# Fireplaces
# 0    54.781159
# 1    39.150769
# 2    54.347826
# 3    38.400000
# Name: YearBuilt, dtype: float64
# Fireplaces
# 0    4
# 1    4
# 2    4
# 3    2
# Name: FullBath, dtype: int64

# %%
c=df[df["MSSubClass"]>60].groupby(lambda x: df['MSSubClass'].loc[x]%20==0)
print(c.agg({'OverallQual': 'std'}))
print(c.agg({'OverallQual': 'mean'}))
print(c.agg({'OverallQual': 'max'}))
c.agg({'OverallQual': 'min'})
# Out:
#        OverallQual
# False     1.193055
# True      1.111021
#        OverallQual
# False     5.556180
# True      6.389908
#        OverallQual
# False           10
# True             9
#        OverallQual
# False            3
# True             4

# %% [markdown]
# ## Feature extraction

# %% [markdown]
# ```Load the complete version of the houses table, entitled "house_prices_larger.csv"```

# %%
df = pd.read_csv('https://raw.githubusercontent.com/roee97/ds_course_ex1/master/house_prices_larger.csv')

# %% [markdown]
# ```As you recall, the feature extraction process is done in order to let us describe the data in more "meaningful" manner. Add the following features to your dataframe:```
# - ```LotArea in squared meters ( it's currently in units of squared feet)```
# - ```1stFlrSF + 2ndFlrSF```
# - ```GarageArea**0.5```
# - ```LotArea / (BedroomAbvGr+1)```
# - ```LotArea / (mean LotArea for houses built in that same year + 1e-5) - you might want to use``` [pandas merge function](https://www.google.com/search?q=pandas+merge&oq=pandas+merge&aqs=chrome..69i57l2j69i59l3j69i60.2080j0j9&sourceid=chrome&ie=UTF-8)
# - ```Ranking of LotArea (largest house has 1, the second largest has 2 and so on)```
# - ```One hot encoding of LotConfig - that is, add feature againts every value possible in LotConfig, which is 1 if the sample's LotConfig is this value and 0 otherwise (consider``` [pandas.get_dummies](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.get_dummies.html))
#
# ```make a list of the names of the features you created.```

# %%
df["LotArea in squared meters"]=df["LotArea"]*0.092903
df["1stFlrSF + 2ndFlrSF"] = df["1stFlrSF"] + df["2ndFlrSF"]
df["GarageArea**0.5"] = df["GarageArea"]**0.5
df["LotArea / (BedroomAbvGr+1)"] = df["LotArea"] / (df["BedroomAbvGr"]+1)
a = pd.merge((df.groupby("YearBuilt").mean()["LotArea"] + 1e-5).reset_index(),df,on="YearBuilt")

df["LotArea / mean"] = a["LotArea_y"]/a["LotArea_x"]
df["rank"] = df["LotArea"].rank()
df[pd.get_dummies(df["LotConfig"]).columns] = pd.get_dummies(df["LotConfig"])
a
# Out:
#       YearBuilt     LotArea_x    Id  MSSubClass  LotFrontage  LotArea_y  \
# 0          1872   5250.000010  1350          70         50.0       5250
# 1          1875   6342.000010  1138          50         54.0       6342
# 2          1880  12246.500010   305          75         87.0      18386
# 3          1880  12246.500010   631          70         50.0       9000
# 4          1880  12246.500010   748          70         65.0      11700
# 5          1880  12246.500010  1133          70         90.0       9900
# 6          1882  17671.000010   992          70        121.0      17671
# 7          1885  11070.000010   107          30         60.0      10800
# 8          1885  11070.000010  1417         190         60.0      11340
# 9          1890   9810.000010   717          70         60.0      10800
# 10         1890   9810.000010   946          50         98.0       8820
# 11         1892  14775.000010   186          75         90.0      22950
# 12         1892  14775.000010  1293          70         60.0       6600
# 13         1893  13500.000010   584          75         75.0      13500
# 14         1898   8100.000010   810          75         90.0       8100
# 15         1900   9393.900010   243          50         63.0       5000
# 16         1900   9393.900010   391          50         50.0       8405
# 17         1900   9393.900010   489         190         60.0      10800
# 18         1900   9393.900010   521         190         60.0      10800
# 19         1900   9393.900010   677          70         60.0       9600
# 20         1900   9393.900010   704         190         76.0       7630
# 21         1900   9393.900010   712          50         66.0       8712
# 22         1900   9393.900010   922          90         67.0       8777
# 23         1900   9393.900010  1063         190         85.0      13600
# 24         1900   9393.900010  1187         190        107.0      10615
# 25         1904  10440.000010   842          70         60.0      10440
# 26         1905  10800.000010  1394         190         60.0      10800
# 27         1906  10320.000010   654          50         60.0      10320
# 28         1908  26519.000010   185          50         92.0       7438
# 29         1908  26519.000010   849          50         75.0      45600
# ...         ...           ...   ...         ...          ...        ...
# 1430       2008  14081.956532   806          20         91.0      12274
# 1431       2008  14081.956532  1059          60         96.0      11308
# 1432       2008  14081.956532  1167          20         64.0      10475
# 1433       2008  14081.956532  1182         120         64.0       5587
# 1434       2008  14081.956532  1229         120         65.0       8769
# 1435       2008  14081.956532  1268          20         89.0      13214
# 1436       2008  14081.956532  1299          60        313.0      63887
# 1437       2008  14081.956532  1317          20         61.0      10226
# 1438       2008  14081.956532  1438          20         96.0      12444
# 1439       2008  14081.956532  1443          60         85.0      11003
# 1440       2008  14081.956532  1452          20         78.0       9262
# 1441       2009   8862.277788    88         160         40.0       3951
# 1442       2009   8862.277788   104          20         94.0      10402
# 1443       2009   8862.277788   158          60         92.0      12003
# 1444       2009   8862.277788   212          20         83.0      10420
# 1445       2009   8862.277788   213          60         72.0       8640
# 1446       2009   8862.277788   413          20          NaN       4403
# 1447       2009   8862.277788   461          60         75.0       8004
# 1448       2009   8862.277788   508          20         75.0       7862
# 1449       2009   8862.277788   516          20         94.0      12220
# 1450       2009   8862.277788   573          60         83.0      13159
# 1451       2009   8862.277788   645          20         85.0       9187
# 1452       2009   8862.277788   763          60         72.0       8640
# 1453       2009   8862.277788   820         120         44.0       6371
# 1454       2009   8862.277788   899          20        100.0      12919
# 1455       2009   8862.277788   915         160         30.0       3000
# 1456       2009   8862.277788   988          20         83.0      10159
# 1457       2009   8862.277788  1166          20         79.0       9541
# 1458       2009   8862.277788  1218          20         72.0       8640
# 1459       2010  11394.000010   379          20         88.0      11394
#
#       OverallQual  OverallCond  YearRemodAdd  MasVnrArea   ...    \
# 0               8            5          1987         0.0   ...
# 1               5            8          1996         0.0   ...
# 2               7            9          2002         0.0   ...
# 3               5            6          1991         0.0   ...
# 4               7            7          2003         0.0   ...
# 5               6            4          1950         0.0   ...
# 6               8            9          1986         0.0   ...
# 7               4            7          1995         0.0   ...
# 8               4            6          1950         0.0   ...
# 9               7            8          1998         0.0   ...
# 10              5            6          1996         0.0   ...
# 11             10            9          1993         0.0   ...
# 12              5            4          1965         0.0   ...
# 13             10            9          2000         0.0   ...
# 14              5            5          1965         0.0   ...
# 15              5            4          1950         0.0   ...
# 16              5            8          1950         0.0   ...
# 17              5            4          1970         0.0   ...
# 18              4            7          2000         0.0   ...
# 19              4            2          1950         0.0   ...
# 20              5            9          1996         0.0   ...
# 21              4            7          1950         0.0   ...
# 22              5            7          2003         0.0   ...
# 23              5            5          1950         0.0   ...
# 24              3            5          1970         0.0   ...
# 25              5            8          2002         0.0   ...
# 26              6            7          2000         0.0   ...
# 27              6            7          1995         0.0   ...
# 28              5            8          1991         0.0   ...
# 29              6            8          1997         0.0   ...
# ...           ...          ...           ...         ...   ...
# 1430            7            5          2008       256.0   ...
# 1431            9            5          2008       154.0   ...
# 1432            8            5          2008        72.0   ...
# 1433            8            5          2008       186.0   ...
# 1434            9            5          2008       766.0   ...
# 1435            9            5          2009         0.0   ...
# 1436           10            5          2008       796.0   ...
# 1437            8            5          2008       270.0   ...
# 1438            8            5          2008       426.0   ...
# 1439           10            5          2008       160.0   ...
# 1440            8            5          2009       194.0   ...
# 1441            6            5          2009        76.0   ...
# 1442            7            5          2009         0.0   ...
# 1443            8            5          2010        84.0   ...
# 1444            6            5          2009         0.0   ...
# 1445            7            5          2009         0.0   ...
# 1446            7            5          2009       432.0   ...
# 1447            8            5          2009       110.0   ...
# 1448            6            5          2009         0.0   ...
# 1449           10            5          2009       305.0   ...
# 1450            7            5          2009         0.0   ...
# 1451            9            5          2009       162.0   ...
# 1452            7            5          2009         0.0   ...
# 1453            7            5          2010       128.0   ...
# 1454            9            5          2010       760.0   ...
# 1455            6            5          2009        76.0   ...
# 1456            9            5          2010       450.0   ...
# 1457            7            5          2009       268.0   ...
# 1458            8            5          2009        72.0   ...
# 1459            9            2          2010       350.0   ...
#
#       1stFlrSF + 2ndFlrSF  GarageArea**0.5  LotArea / (BedroomAbvGr+1)  \
# 0                    2153         0.000000                 1050.000000
# 1                    1020         0.000000                 2114.000000
# 2                    3493        29.495762                 4596.500000
# 3                    1750        15.491933                 2250.000000
# 4                    2640        29.393877                 2340.000000
# 5                    2210        14.317821                 1650.000000
# 6                    1742        20.591260                 3534.200000
# 7                    1047        16.522712                 3600.000000
# 8                    2290        23.664319                 2268.000000
# 9                    2554        26.532998                 2700.000000
# 10                   1749        21.354157                 2940.000000
# 11                   3036        28.982753                 4590.000000
# 12                   2372        20.784610                 1320.000000
# 13                   2775        29.664794                 3375.000000
# 14                   2138        18.973666                 2700.000000
# 15                   1440        18.761663                 1250.000000
# 16                   1367        19.595918                 1681.000000
# 17                   2414        22.803509                 2700.000000
# 18                   1294         0.000000                 2700.000000
# 19                   1774        27.910571                 1920.000000
# 20                   1812        25.922963                 1526.000000
# 21                   1178        19.595918                 2904.000000
# 22                   2200         0.000000                 1755.400000
# 23                   2337        23.664319                 2266.666667
# 24                   1699        20.493902                 2653.750000
# 25                   1539        26.191602                 2610.000000
# 26                   1912        25.922963                 2700.000000
# 27                   1469        14.696938                 2580.000000
# 28                   1252        24.000000                 1859.500000
# 29                   2358        18.973666                 7600.000000
# ...                   ...              ...                         ...
# 1430                 1428        23.537205                 3068.500000
# 1431                 2184        28.913665                 2827.000000
# 1432                 1694        27.856777                 2618.750000
# 1433                 1652        21.954498                 1862.333333
# 1434                 1702        32.434549                 4384.500000
# 1435                 2018        27.313001                 3303.500000
# 1436                 5642        37.656341                15971.750000
# 1437                 1630        29.325757                 2556.500000
# 1438                 1932        27.820855                 4148.000000
# 1439                 2007        28.495614                 2750.750000
# 1440                 1578        28.982753                 2315.500000
# 1441                 1224        22.978251                 1317.000000
# 1442                 1226        27.202941                 2600.500000
# 1443                 1968        26.076810                 2400.600000
# 1444                 1212        21.447611                 2605.000000
# 1445                 1852        25.377155                 2160.000000
# 1446                 1478        22.000000                 1467.666667
# 1447                 1935        23.494680                 2001.000000
# 1448                 1218        26.000000                 2620.666667
# 1449                 2020        30.000000                 3055.000000
# 1450                 1692        25.495098                 3289.750000
# 1451                 1766        21.863211                 3062.333333
# 1452                 1547        24.779023                 2160.000000
# 1453                 1358        22.000000                 2123.666667
# 1454                 2364        28.635642                 4306.333333
# 1455                 1224        22.978251                 1000.000000
# 1456                 1940        24.617067                 2539.750000
# 1457                 1502        25.377155                 2385.250000
# 1458                 1314        23.494680                 2160.000000
# 1459                 1856        28.879058                 5697.000000
#
#       LotArea / mean    rank  Corner  CulDSac  FR2  FR3  Inside
# 0           2.235727   155.0       0        0    0    0       1
# 1           1.254283   241.0       0        0    0    0       1
# 2           0.848999  1399.0       0        0    0    0       1
# 3           1.006419   631.5       1        0    0    0       0
# 4           1.031203  1108.5       1        0    0    0       0
# 5           0.815890   820.5       0        0    0    0       1
# 6           1.231398  1393.0       1        0    0    0       0
# 7           1.006028   987.5       0        0    0    0       1
# 8           1.459024  1063.5       0        0    0    0       1
# 9           0.193601   987.5       0        0    0    0       1
# 10          1.115364   594.0       1        0    0    0       0
# 11          1.115825  1424.0       0        0    0    0       1
# 12          0.933737   250.5       1        0    0    0       0
# 13          0.360526  1258.5       0        0    0    0       1
# 14          1.496063   444.5       1        0    0    0       0
# 15          1.197736   145.0       1        0    0    0       0
# 16          1.046290   502.5       0        0    0    0       1
# 17          2.253991   987.5       1        0    0    0       0
# 18          0.920096   987.5       0        0    0    0       1
# 19          0.306485   767.5       0        0    0    0       1
# 20          0.654347   376.0       0        0    0    0       1
# 21          0.218142   557.0       0        0    0    0       1
# 22          1.388394   581.0       0        0    0    0       1
# 23          0.278809  1267.5       0        0    0    0       1
# 24          1.573726   948.0       1        0    0    0       0
# 25          0.663341   924.0       0        0    0    0       1
# 26          0.862446   987.5       0        0    0    0       1
# 27          1.311880   899.0       0        0    0    0       1
# 28          0.826020   351.0       0        0    0    0       1
# 29          1.313031  1448.0       0        0    0    0       1
# ...              ...     ...     ...      ...  ...  ...     ...
# 1430        0.805005  1177.0       0        0    1    0       0
# 1431        1.217208  1058.0       0        0    0    0       1
# 1432        1.283218   929.0       1        0    0    0       0
# 1433        0.459179   176.0       0        0    0    0       1
# 1434        1.383491   576.0       1        0    0    0       0
# 1435        0.341983  1244.0       0        0    0    0       1
# 1436        1.361162  1455.0       1        0    0    0       0
# 1437        1.563000   886.0       0        0    0    0       1
# 1438        0.726178  1194.0       0        0    1    0       0
# 1439        1.173739  1015.0       0        0    0    0       1
# 1440        1.036641   697.0       0        0    0    0       1
# 1441        0.913468    93.0       1        0    0    0       0
# 1442        1.322208   916.0       1        0    0    0       0
# 1443        0.805768  1143.0       1        0    0    0       0
# 1444        1.310382   919.0       1        0    0    0       0
# 1445        1.345891   550.5       0        0    0    0       1
# 1446        0.842195   115.0       0        0    0    0       1
# 1447        1.598843   432.0       0        0    0    0       1
# 1448        0.630767   409.0       0        0    0    0       1
# 1449        3.025503  1170.0       0        0    0    0       1
# 1450        0.401891  1241.0       1        0    0    0       0
# 1451        0.887858   680.5       0        0    0    0       1
# 1452        1.158124   550.5       0        0    0    0       1
# 1453        0.924797   242.0       0        0    0    0       1
# 1454        0.878122  1223.0       0        0    0    0       1
# 1455        1.188442    56.0       0        0    0    0       1
# 1456        1.090105   870.0       0        0    0    0       1
# 1457        0.748147   742.0       0        0    0    0       1
# 1458        1.092273   550.5       0        0    0    0       1
# 1459        0.767396  1071.0       1        0    0    0       0
#
# [1460 rows x 51 columns]

# %%
names=["LotArea in squared meters","1stFlrSF + 2ndFlrSF","GarageArea**0.5","LotArea / (BedroomAbvGr+1)","LotArea / mean","rank","Corner","CulDSac","FR2","FR3","Inside"]

# %% [markdown]
# ## Simple linear model

# %% [markdown]
# ```Next, we will train a simple linear model, as seen in class, to predict SalePrice. Use the features you computed. Create train and test segments, normalize the data (both the features and the target) and use a linear model. Make sure you don't somehow use the test data when training your model (or when normalizing your data).```

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

# %%
data = df[names]
target = df["SalePrice"]/np.max(df["SalePrice"])

train = data[:-100]
test = data[-100:]
 
lm = LinearRegression(normalize =True)
lm.fit(train,target[:-100])

plt.plot([0,1],[0,1],'r--')
plt.scatter(target[-100:],lm.predict(test))
plt.xlabel("actual")
plt.ylabel("predicted")
mean_squared_error(target[-100:],lm.predict(test))
# Out:
# 0.004321220174556937

# %% [markdown]
# ```Next, we will add extra features: for any feature you computed earlier, add feature**2 and feature**3. Now use Ridge regression (regularized linear regression, as we discussed in class). Draw graphs of the loss computed on the train and on the validation as a function of the regularization parameter, for``` 1$\leq\alpha\leq$30. ```What regularization would it be best to take?```

# %%
from sklearn.linear_model import Ridge
data = df[names]
target = df["SalePrice"]/np.max(df["SalePrice"])

for a in data.columns:
    data["{}**2".format(a)]=data[a]**2
    data["{}**3".format(a)]=data[a]**3
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
train = data[:-100]
test = data[-100:]


for i in range(10,310,5):
    lm = Ridge(alpha=i/10, normalize=True)
    lm.fit(train,target[:-100])


    plt.scatter(i/10,mean_squared_error(target[-100:],lm.predict(test)))
    plt.xlabel("alpha")
    plt.ylabel("loss")

# %%
looks like the lowest loss is achieved by the smallest alpha. about 1.5 is the best.
