# %% [markdown]
# # Basics of Neural networks and other stuff
# ```In this exercise you will experience working with keras, a useful tool for designing and training neural networks.```
#
# ```~Ittai Haran```

# %% [markdown]
# ## Stage 1- predicting engineered functions
# ```Here you will design a simple fully connected network to predict a few simple functions. You will try different activation functions and different architectures (number of layers, size of layers).```

# %% [markdown]
# ```The first experiment will be guided:```
# - ```Read the first dataframe - function_1.csv.``` (in: https://drive.google.com/open?id=19Y9f2pkUwP7nrgbKCmCGHEomHmA0pwqx)
# - ```Plot y against x. can you guess the function y(x)?```
# - ```Split you data to train segment (70%) and test segment (30%).```
# - ```Write a fully connected neural network with one hidden layer with 3 units. I suggest using the``` [functional API](https://keras.io/getting-started/functional-api-guide/) - ```you can also find there examples for simple working with keras.```
# - ```Use tanh as an activation function for the hidden layer and a linear activation for the output layer.```
# - ```Use model.summary() to look at your model's architecture.```
# - ```Use mean squared error as the loss function and SGD (stochastic gradient descent) as the optimizer.```
# - ```Try training the network with different batch's sizes (don't be afraid to use many epochs- you don't have a lot of data).```
# - ```Plot y against x and f(x) against x on the same graph.```
# - ```Compute the loss on the test segment.```
# - ```Can you use a smaller hidden layer?```

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from keras.layers import Dense, Input
from keras.models import Model
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('function_1.csv').sort_values('x')
df.index = range(len(df))
plt.plot(df['x'], df['y'])
plt.show()

main_input = Input((1,))
hidden = Dense(3, activation='tanh')(main_input)
main_output = Dense(1, activation='linear')(hidden)
model = Model(inputs = [main_input], outputs = [main_output])
model.compile(loss = 'mse', optimizer = 'sgd')

index_train, index_test = train_test_split(df.index, train_size = 0.7, test_size = 0.3)
X_train = df['x'].iloc[sorted(index_train)]
X_test = df['x'].iloc[sorted(index_test)]
Y_train = df['y'].iloc[sorted(index_train)]
Y_test = df['y'].iloc[sorted(index_test)]
model.fit(X_train, Y_train, batch_size = 5, epochs = 30, verbose=2)

plt.plot(X_train, Y_train)
plt.plot(X_test, model.predict(X_test))
plt.show()
print 'loss on test segment: {0}'.format(mean_squared_error(Y_test, model.predict(X_test)))
# Out:
# Epoch 1/30
#  - 2s - loss: 0.0995
# Epoch 2/30
#  - 2s - loss: 0.0107
# Epoch 3/30
#  - 2s - loss: 0.0059
# Epoch 4/30
#  - 2s - loss: 0.0054
# Epoch 5/30
#  - 2s - loss: 0.0049
# Epoch 6/30
#  - 2s - loss: 0.0045
# Epoch 7/30
#  - 2s - loss: 0.0041
# Epoch 8/30
#  - 2s - loss: 0.0038
# Epoch 9/30
#  - 2s - loss: 0.0035
# Epoch 10/30
#  - 2s - loss: 0.0032
# Epoch 11/30
#  - 2s - loss: 0.0029
# Epoch 12/30
#  - 2s - loss: 0.0027
# Epoch 13/30
#  - 2s - loss: 0.0024
# Epoch 14/30
#  - 2s - loss: 0.0022
# Epoch 15/30
#  - 2s - loss: 0.0020
# Epoch 16/30
#  - 2s - loss: 0.0018
# Epoch 17/30
#  - 2s - loss: 0.0017
# Epoch 18/30
#  - 2s - loss: 0.0015
# Epoch 19/30
#  - 2s - loss: 0.0013
# Epoch 20/30
#  - 2s - loss: 0.0012
# Epoch 21/30
#  - 2s - loss: 0.0011
# Epoch 22/30
#  - 2s - loss: 9.6093e-04
# Epoch 23/30
#  - 2s - loss: 8.5724e-04
# Epoch 24/30
#  - 2s - loss: 7.6252e-04
# Epoch 25/30
#  - 2s - loss: 6.7799e-04
# Epoch 26/30
#  - 2s - loss: 6.0343e-04
# Epoch 27/30
#  - 2s - loss: 5.3493e-04
# Epoch 28/30
#  - 2s - loss: 4.7586e-04
# Epoch 29/30
#  - 2s - loss: 4.2230e-04
# Epoch 30/30
#  - 2s - loss: 3.7479e-04
# loss on test segment: 0.000355921249672

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, 1)                 0
# _________________________________________________________________
# dense_17 (Dense)             (None, 3)                 6
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 4
# =================================================================
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ```For the second experiment use the dataframe function_2.csv. Here you might need to have more layers. You might want to consider different``` [optimizers](https://keras.io/optimizers/), ```rather than SGD (for example, Adam).```
#
# (```function_2.csv can be found in:``` https://drive.google.com/open?id=1Fk32cP-4DSZ6v175UDVz_OChHE-dFLzq)

# %%
df = pd.read_csv('function_2.csv').sort_values('x')
df.index = range(len(df))
plt.plot(df['x'], df['y'])
plt.show()

main_input = Input((1,))
hidden = Dense(3, activation='tanh')(main_input)
hidden = Dense(3, activation='tanh')(hidden)
hidden = Dense(3, activation='tanh')(hidden)
hidden = Dense(3, activation='tanh')(hidden)
main_output = Dense(1, activation='linear')(hidden)
model = Model(inputs = [main_input], outputs = [main_output])
model.compile(loss = 'mse', optimizer = 'adam')

index_train, index_test = train_test_split(df.index, train_size = 0.7, test_size = 0.3)
X_train = df['x'].iloc[sorted(index_train)]
X_test = df['x'].iloc[sorted(index_test)]
Y_train = df['y'].iloc[sorted(index_train)]
Y_test = df['y'].iloc[sorted(index_test)]
model.fit(X_train, Y_train, batch_size = 5, epochs = 20, verbose=2)

plt.plot(X_train, Y_train)
plt.plot(X_test, model.predict(X_test))
plt.show()
print 'loss on test segment: {0}'.format(mean_squared_error(Y_test, model.predict(X_test)))
# Out:
# Epoch 1/20
#  - 4s - loss: 8.9979e-04
# Epoch 2/20
#  - 3s - loss: 8.5079e-04
# Epoch 3/20
#  - 3s - loss: 8.3463e-04
# Epoch 4/20
#  - 3s - loss: 7.8496e-04
# Epoch 5/20
#  - 3s - loss: 5.6241e-04
# Epoch 6/20
#  - 3s - loss: 1.2463e-04
# Epoch 7/20
#  - 3s - loss: 4.5670e-05
# Epoch 8/20
#  - 3s - loss: 4.8192e-05
# Epoch 9/20
#  - 3s - loss: 4.6034e-05
# Epoch 10/20
#  - 3s - loss: 4.4320e-05
# Epoch 11/20
#  - 3s - loss: 4.3467e-05
# Epoch 12/20
#  - 3s - loss: 4.2261e-05
# Epoch 13/20
#  - 3s - loss: 4.3561e-05
# Epoch 14/20
#  - 3s - loss: 4.0532e-05
# Epoch 15/20
#  - 3s - loss: 4.1487e-05
# Epoch 16/20
#  - 3s - loss: 3.9606e-05
# Epoch 17/20
#  - 3s - loss: 4.0389e-05
# Epoch 18/20
#  - 3s - loss: 3.9656e-05
# Epoch 19/20
#  - 3s - loss: 3.6847e-05
# Epoch 20/20
#  - 3s - loss: 3.6955e-05
# loss on test segment: 2.99374122398e-05

# %% [markdown]
# ```For the third experiment use the dataframe function_3.csv. Try different activation functions. How many layers you had to take?```
#
# (```function_3.csv can be found in:``` https://drive.google.com/open?id=1-XTfy6Wf0_WhEKJ9AnUGENBZRSNXkwNe)

# %%
df = pd.read_csv('function_3.csv').sort_values('x')
df.index = range(len(df))
plt.plot(df['x'], df['y'])
plt.show()

main_input = Input((1,))
hidden = Dense(3, activation='tanh')(main_input)
hidden = Dense(10, activation='tanh')(hidden)
hidden = Dense(10, activation='tanh')(hidden)
hidden = Dense(10, activation='tanh')(hidden)
hidden = Dense(10, activation='tanh')(hidden)
hidden = Dense(10, activation='tanh')(hidden)
hidden = Dense(5, activation='tanh')(hidden)
hidden = Dense(3, activation='tanh')(hidden)
main_output = Dense(1, activation='linear')(hidden)
model = Model(inputs = [main_input], outputs = [main_output])
model.compile(loss = 'mse', optimizer = 'adam')

index_train, index_test = train_test_split(df.index, train_size = 0.7, test_size = 0.3)
X_train = df['x'].iloc[sorted(index_train)]
X_test = df['x'].iloc[sorted(index_test)]
Y_train = df['y'].iloc[sorted(index_train)]
Y_test = df['y'].iloc[sorted(index_test)]
model.fit(X_train, Y_train, batch_size = 20, epochs = 30, verbose=2)

plt.plot(X_train, Y_train)
plt.plot(X_test, model.predict(X_test))
plt.show()
print 'loss on test segment: {0}'.format(mean_squared_error(Y_test, model.predict(X_test)))
# Out:
# Epoch 1/30
#  - 12s - loss: 0.4368
# Epoch 2/30
#  - 12s - loss: 0.3368
# Epoch 3/30
#  - 11s - loss: 0.1936
# Epoch 4/30
#  - 11s - loss: 0.0678
# Epoch 5/30
#  - 12s - loss: 0.0153
# Epoch 6/30
#  - 12s - loss: 0.0153
# Epoch 7/30
#  - 12s - loss: 0.0161
# Epoch 8/30
#  - 12s - loss: 0.0109
# Epoch 9/30
#  - 12s - loss: 0.0122
# Epoch 10/30
#  - 11s - loss: 0.0083
# Epoch 11/30
#  - 11s - loss: 0.0109
# Epoch 12/30
#  - 12s - loss: 0.0095
# Epoch 13/30
#  - 11s - loss: 0.0104
# Epoch 14/30
#  - 11s - loss: 0.0103
# Epoch 15/30
#  - 12s - loss: 0.0082
# Epoch 16/30
#  - 12s - loss: 0.0107
# Epoch 17/30
#  - 12s - loss: 0.0075
# Epoch 18/30
#  - 12s - loss: 0.0079
# Epoch 19/30
#  - 11s - loss: 0.0091
# Epoch 20/30
#  - 12s - loss: 0.0066
# Epoch 21/30
#  - 12s - loss: 0.0089
# Epoch 22/30
#  - 11s - loss: 0.0108
# Epoch 23/30
#  - 11s - loss: 0.0067
# Epoch 24/30
#  - 12s - loss: 0.0082
# Epoch 25/30
#  - 12s - loss: 0.0078
# Epoch 26/30
#  - 12s - loss: 0.0071
# Epoch 27/30
#  - 12s - loss: 0.0060
# Epoch 28/30
#  - 12s - loss: 0.0055
# Epoch 29/30
#  - 12s - loss: 0.0075
# Epoch 30/30
#  - 12s - loss: 0.0062
# loss on test segment: 0.000626725048651

# %% [markdown]
# ```As you maybe could've guessed, the function you fitted is``` $y = sin(x)$. ```Hence one might think it would be easy to fit a network with only one neuron, with activation of the sinus function. Try it: define a neural network with a single input and a single output, with no hidden layers, and use a sinus activation, to approximate function_3. Next we will understand why using sinus as an activation function is not a good idea.```
#
# ```You can use sin_activation provided below as the sinus activation: instead of writing activation='tanh' or activation='sigmoid', use activation=sin_activation.```

# %%
import keras.backend as K
def sin_activation(vec):
    return K.sin(vec)

# %%
df = pd.read_csv('function_3.csv').sort_values('x')
df.index = range(len(df))
plt.plot(df['x'], df['y'])
plt.show()

main_input = Input((1,))
main_output = Dense(1, activation=sin_activation)(main_input)
model = Model(inputs = [main_input], outputs = [main_output])
model.compile(loss = 'mse', optimizer = 'adam')

index_train, index_test = train_test_split(df.index, train_size = 0.7, test_size = 0.3)
X_train = df['x'].iloc[sorted(index_train)]
X_test = df['x'].iloc[sorted(index_test)]
Y_train = df['y'].iloc[sorted(index_train)]
Y_test = df['y'].iloc[sorted(index_test)]

callbacker = WeightsHistory()

model.fit(X_train, Y_train, batch_size = 100, epochs = 10, verbose=2, callbacks=[callbacker])

plt.plot(X_train, Y_train)
plt.plot(X_test, model.predict(X_test))
plt.show()
print 'loss on test segment: {0}'.format(mean_squared_error(Y_test, model.predict(X_test)))
# Out:
# Epoch 1/10
#  - 2s - loss: 0.5653
# Epoch 2/10
#  - 2s - loss: 0.4901
# Epoch 3/10
#  - 2s - loss: 0.4899
# Epoch 4/10
#  - 2s - loss: 0.4900
# Epoch 5/10
#  - 2s - loss: 0.4901
# Epoch 6/10
#  - 2s - loss: 0.4900
# Epoch 7/10
#  - 2s - loss: 0.4899
# Epoch 8/10
#  - 2s - loss: 0.4900
# Epoch 9/10
#  - 2s - loss: 0.4900
# Epoch 10/10
#  - 2s - loss: 0.4900
# loss on test segment: 0.490237930534

# %% [markdown]
# ```Let's explore the sinus activation. For this we will simplify the settings. We will generate 3 samples, with ```
# $x = [0, 0.5, 1]$ ``` and ``` $y=[sin(0), sin(0.5), sin(1)]$. ```We will keep using the simplest neural network, that has one input and one output, with no hidden layers. Hence the possible functions that the network can give us are functions of the form```
# <center>$y=sin(a\cdot x+b)$.<center>
#
# ```We can use the simple setting to compute and visualize the loss surface. As you recall, the loss is given by```
# <center>$\sum_i{(sin(a\cdot x_i+b)-y_i)^2}$<center>
#
# ```Create a matrix so that in the (i,j) entry there will be the loss for ``` $a = \frac{2\pi}{600}\cdot i$ and $b= \frac{2\pi}{600}\cdot j$. ```Visualize this matrix using plt.imshow.```

# %%
x = np.array([0,0.5,1])
y = np.sin(x)
resolution = 600
pi_mul = 2
a_s, b_s = np.meshgrid(np.linspace(-pi_mul*np.pi,pi_mul*np.pi,resolution),
                       np.linspace(-pi_mul*np.pi,pi_mul*np.pi,resolution))

sums = np.sum((np.sin(a_s.reshape(resolution,resolution,1)*x.reshape(1,1,3)
                      +b_s.reshape(resolution,resolution,1)) - y.reshape(1,1,3))**2, axis=-1)

plt.imshow(sums, interpolation='none')
plt.colorbar()
plt.show()

# %% [markdown]
# ```Do the same for the beloved activation, tanh. Based on the images, what makes sinus a poor activation function and tanh a good activation function? answer in ``` $\underline{a\ cell\ below}$.

# %%
x = np.array([0,0.5,1])
y = np.tanh(x)
resolution = 600
pi_mul = 2
a_s, b_s = np.meshgrid(np.linspace(-pi_mul*np.pi,pi_mul*np.pi,resolution),
                       np.linspace(-pi_mul*np.pi,pi_mul*np.pi,resolution))

sums = np.sum((np.tanh(a_s.reshape(resolution,resolution,1)*x.reshape(1,1,3)
                      +b_s.reshape(resolution,resolution,1)) - y.reshape(1,1,3))**2, axis=-1)

plt.imshow(sums, interpolation='none')
plt.colorbar()
plt.show()

# %% [markdown]
# ### Bonus:
# ```When training neural networks using keras we can use callback functions: There are functions that are called automatically during the training and can be of several usages. For example, we can use a callback function to save our model to a file upon the ending of an epoch.
# Below you will find a custom callback that keeps the weights for a and b in your sinus model. Use it like this:```
#
# ``` python
# wh = WeightsHistory()
# model.fit(X_train, Y_train, batch_size = 100, epochs = 10, verbose=2, callbacks=[wh])
# ```
#
# ```After you try training your model using the sinus activation you can plot the path your model took on the a-b plane. Add to your loss surface visualization a plot showing the a-b values during training.```
#
# ```Note: after using plt.imshow you got an image of the size``` $600\times 600$. ```You will have to scale your a-b path accordingly to see it on the same graph. Try zooming (by changing the scale of the image, enlarging the size of your image or using any other mean) to get a better view of the a-b path. Can you explain why didn't you get a convergence?```

# %%
from keras.callbacks import Callback
class WeightsHistory(Callback):
    def on_train_begin(self, logs={}):
        self.a_s = []
        self.b_s = []

    def on_batch_end(self, batch, logs={}):
        weights = self.model.get_weights()
        self.a_s.append(weights[0][0][0])
        self.b_s.append(weights[1][0])

# %%
x = np.array([0,0.5,1])
y = np.sin(x)
resolution = 600
pi_mul = 0.2
a_s, b_s = np.meshgrid(np.linspace(-pi_mul*np.pi,pi_mul*np.pi,resolution),
                       np.linspace(-pi_mul*np.pi,pi_mul*np.pi,resolution))

sums = np.sum((np.sin(a_s.reshape(resolution,resolution,1)*x.reshape(1,1,3)
                      +b_s.reshape(resolution,resolution,1)) - y.reshape(1,1,3))**2, axis=-1)

plt.imshow(sums, interpolation='none')
plt.colorbar()

change_lambda = lambda x: (300/(pi_mul*np.pi))*x+300
plt.plot(change_lambda(np.array(callbacker.a_s)), change_lambda(np.array(callbacker.b_s)), c='r')
plt.show()

# %% [markdown]
# ## Stage 2- predict digits from MNIST
# ```Use your knowledge to create a good prediction for the MNIST dataset. Note that this a classification problem, and you will have to use a different loss: for example, the binary cross entropy (log loss). Furthermore, you might want to use softmax to generate predictions. You can use activation='softmax' in the last layer of your network.
# good luck!```

# %%
from keras.datasets import mnist
(X_train_images, Y_train_num), (X_test_images, Y_test_num) = mnist.load_data()
plt.imshow(X_train_images[0])
plt.show()

X_train = X_train_images.reshape(-1,784)
X_test = X_test_images.reshape(-1,784)
Y_train = pd.get_dummies(Y_train_num)
Y_test = pd.get_dummies(Y_test_num)

# %%
from sklearn.metrics import accuracy_score
main_input = Input((784,))
hidden = Dense(100, activation='tanh')(main_input)
hidden = Dense(50, activation='tanh')(hidden)
hidden = Dense(30, activation='tanh')(hidden)
main_output = Dense(10, activation='softmax')(hidden)
model = Model(inputs = [main_input], outputs = [main_output])
model.compile(loss = 'binary_crossentropy', optimizer = 'adam')

model.fit(X_train, Y_train, batch_size = 100, epochs = 30, verbose=2)
print 'loss on test segment: {0}'.format(accuracy_score(Y_test_num, np.argmax(model.predict(X_test), axis=-1)))

# %% [markdown]
# ## Stage 3 - exploring deep neural networks
# ```In this part we will explore the problems with training deep networks.```

# %% [markdown]
# ```We will work with the simplest data possible and will try to approximate the identity function, with one feature.
# Generate 10,000 samples using np.random.random and have ``` $y=x$. ```Create a neural network with a single hidden layer with 3 neurons in it and sigmoid activation. Approximate the identity function.```

# %%
df = pd.DataFrame(np.random.random((10000,1)).repeat(2,1), columns=['x', 'y'])
df.index = range(len(df))
plt.plot(df['x'], df['y'])
plt.show()

index_train, index_test = train_test_split(df.index, train_size = 0.7, test_size = 0.3)
X_train = df['x'].iloc[sorted(index_train)]
X_test = df['x'].iloc[sorted(index_test)]
Y_train = df['y'].iloc[sorted(index_train)]
Y_test = df['y'].iloc[sorted(index_test)]

# %%
main_input = Input((1,))
hidden = Dense(3, activation='sigmoid')(main_input)
main_output = Dense(1, activation='linear')(hidden)
model = Model(inputs = [main_input], outputs = [main_output])
model.compile(loss = 'mse', optimizer = 'adam')

model.fit(X_train, Y_train, batch_size = 10, epochs = 15, verbose=2)

plt.plot(X_train, Y_train)
plt.plot(X_test, model.predict(X_test))
plt.show()
print 'loss on test segment: {0}'.format(mean_squared_error(Y_test, model.predict(X_test)))
# Out:
# Epoch 1/15
#  - 2s - loss: 0.1616
# Epoch 2/15
#  - 1s - loss: 0.0462
# Epoch 3/15
#  - 1s - loss: 0.0308
# Epoch 4/15
#  - 1s - loss: 0.0169
# Epoch 5/15
#  - 1s - loss: 0.0067
# Epoch 6/15
#  - 1s - loss: 0.0016
# Epoch 7/15
#  - 1s - loss: 2.6306e-04
# Epoch 8/15
#  - 1s - loss: 9.8443e-05
# Epoch 9/15
#  - 1s - loss: 7.9705e-05
# Epoch 10/15
#  - 1s - loss: 6.5994e-05
# Epoch 11/15
#  - 1s - loss: 5.4393e-05
# Epoch 12/15
#  - 1s - loss: 4.5099e-05
# Epoch 13/15
#  - 1s - loss: 3.8735e-05
# Epoch 14/15
#  - 1s - loss: 3.5257e-05
# Epoch 15/15
#  - 1s - loss: 3.3551e-05
# loss on test segment: 3.40017646965e-05

# %% [markdown]
# ```Add 50 hidden layers to your network, again, with 3 neurons in each layer and sigmoid activatoin. Try approximating the identity function using this network.```

# %%
main_input = Input((1,))
hidden = Dense(3, activation='sigmoid')(main_input)
for i in xrange(49):
    hidden = Dense(3, activation='sigmoid')(hidden)
main_output = Dense(1, activation='linear')(hidden)
model = Model(inputs = [main_input], outputs = [main_output])
model.compile(loss = 'mse', optimizer = 'adam')

model.fit(X_train, Y_train, batch_size = 10, epochs = 15, verbose=2)

plt.plot(X_train, Y_train)
plt.plot(X_test, model.predict(X_test))
plt.show()
print 'loss on test segment: {0}'.format(mean_squared_error(Y_test, model.predict(X_test)))
# Out:
# Epoch 1/15
#  - 10s - loss: 0.1185
# Epoch 2/15
#  - 9s - loss: 0.0837
# Epoch 3/15
#  - 9s - loss: 0.0838
# Epoch 4/15
#  - 7s - loss: 0.0837
# Epoch 5/15
#  - 7s - loss: 0.0838
# Epoch 6/15
#  - 9s - loss: 0.0839
# Epoch 7/15
#  - 9s - loss: 0.0838
# Epoch 8/15
#  - 9s - loss: 0.0837
# Epoch 9/15
#  - 9s - loss: 0.0838
# Epoch 10/15
#  - 9s - loss: 0.0838
# Epoch 11/15
#  - 9s - loss: 0.0838
# Epoch 12/15
#  - 9s - loss: 0.0838
# Epoch 13/15
#  - 10s - loss: 0.0837
# Epoch 14/15
#  - 9s - loss: 0.0838
# Epoch 15/15
#  - 9s - loss: 0.0838
# loss on test segment: 0.086690583347

# %% [markdown]
# ```Why isn't it working? Explain it in ``` $\underline{a\ cell\ below}$. ```In your explanation regard the process of back propagation and the formula of gradients found in the first layers of the network. Regard also the possible values of the derivative of the sigmoid function.```

# %% [markdown]
# ```Run the cell below. In weight_grads you will have a list of the gradients computed in every layer. For each layer take the maximum absolute value of the gradients. Plot a graph of the maximum values against the number of layer. Also plot it in logarithmic scale. Use it to justify your answer from before in ``` $\underline{a\ cell\ below}$.

# %%
import numpy as np
from keras import backend as K

def get_weight_grad(model, inputs, outputs):
    """ Gets gradient of model for given inputs and outputs for all weights"""
    grads = model.optimizer.get_gradients(model.total_loss, model.trainable_weights)
    symb_inputs = (model._feed_inputs + model._feed_targets + model._feed_sample_weights)
    f = K.function(symb_inputs, grads)
    x, y, sample_weight = model._standardize_user_data(inputs, outputs)
    output_grad = f(x + y + sample_weight)
    return output_grad

weight_grads = get_weight_grad(model, X_train, Y_train)

# %%
plt.plot(range(1,len(weight_grads)+1), map(lambda x: np.max(np.abs(x.reshape(-1))), weight_grads))
plt.xlabel('#layer')
plt.ylabel('gradient maximum absolute value')
plt.title('Gradients size againts the number of the layer')
plt.show()

plt.plot(range(1,len(weight_grads)+1), map(lambda x: np.log10(np.max(np.abs(x.reshape(-1)))), weight_grads))
plt.xlabel('#layer')
plt.ylabel('gradient maximum absolute value')
plt.title('Gradients size againts the number of the layer, logarhitmic scale')
plt.show()
